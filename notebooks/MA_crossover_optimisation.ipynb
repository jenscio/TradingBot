# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
def MA_CROSSOVER(df : pd.DataFrame, lookback_1 : int, lookback_2 : int) :

    dF = df.copy()
 
    dF['SMA'] = dF['Close'].rolling(lookback_1 - 1).mean()
    dF['LMA'] = dF['Close'].rolling(lookback_2 - 1).mean()

    Signal = pd.Series(np.full(len(dF),np.nan), index = dF.index)
    Signal.loc[dF['SMA'] > dF['LMA']] = 1
    Signal.loc[dF['SMA'] < dF['LMA']] = -1
    Signal = Signal.ffill()  

    ##
    counter = 0
    entry = Signal.diff()
    for val in entry : 
        if abs(val) == 2 :
            counter += 1
    ##
    return Signal, counter

# %%
def OPTI_MACO(df : pd.DataFrame) :

    best_profitfactor = 0
    best_lookback_1 = -1
    best_lookback_2 = -1

    returns = np.log(df['Close']).diff().shift(-1).squeeze()

    for lookback1 in range(9,169) :
        for lookback2 in range(9,169) :
            if (lookback1 < lookback2) : 
                
                signal = MA_CROSSOVER(df,lookback1, lookback2)[0]
                SR = (signal * returns).dropna() 
                signal_profitfactor = SR[SR > 0].sum() / SR[SR < 0].abs().sum()
            
                if (signal_profitfactor > best_profitfactor) :
                    best_profitfactor = signal_profitfactor
                    best_lookback_1 = lookback1
                    best_lookback_2 = lookback2

                
                #plt.plot(SR.cumsum(), label = f" {lookback1} : {lookback2} ")
                #plt.legend(loc=2)
                #plt.show()
                

    return best_lookback_1, best_lookback_2, best_profitfactor

# %%
def walkforward_MA(ohlc: pd.DataFrame, train_lookback: int = 365 * 4, train_step: int = 30):

    n = len(ohlc)
    wf_signal = np.full(n, np.nan)
    tmp_signal = None
    
    next_train = train_lookback
    for i in range(next_train, n):
        if i == next_train:
            bl1, bl2 , _ = OPTI_MACO(ohlc.iloc[i-train_lookback:i])
            tmp_signal, _ = MA_CROSSOVER(ohlc, bl1, bl2)
            next_train += train_step
        
        wf_signal[i] = tmp_signal.iloc[i]
    
    return wf_signal

# %%
symbol = 'GLD'

df_gold = yf.download([symbol], start = '2016-01-31', end = '2020-01-31', interval="1d")

bestLB1, bestLB2, bestPF = OPTI_MACO(df_gold)

SIG1, nb_t_gold = MA_CROSSOVER(df_gold, bestLB1, bestLB2)

df_gold['returns'] = np.log(df_gold['Close']).diff().shift(-1) 
df_gold['system_returns'] = df_gold['returns']*SIG1
plt.plot(np.exp(df_gold['system_returns']).cumprod(), label = 'Rendement')
plt.legend(loc=2)
plt.show()


print(f"best lookback 1 is : {bestLB1}")
print(f"best lookback 2 is : {bestLB2}")
print(f"best profit factor is : {bestPF}")
print(f"the number of trades for these lookbacks is {nb_t_gold}")
# Out:
# /var/folders/nj/fvwmdhv14_10q8jn30_jtzkm0000gn/T/ipykernel_26334/1113520400.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_gold = yf.download([symbol], start = '2016-01-31', end = '2020-01-31', interval="1d")
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 symbol = 'GLD'
#       3 df_gold = yf.download([symbol], start = '2016-01-31', end = '2020-01-31', interval="1d")
# ----> 5 bestLB1, bestLB2, bestPF = OPTI_MACO(df_gold)
#       7 SIG1, nb_t_gold = MA_CROSSOVER(df_gold, bestLB1, bestLB2)
#       9 df_gold['returns'] = np.log(df_gold['Close']).diff().shift(-1)
#
# Cell In[3], line 13, in OPTI_MACO(df)
#      10 for lookback2 in range(9,169) :
#      11     if (lookback1 < lookback2) :
# ---> 13         signal = MA_CROSSOVER(df,lookback1, lookback2)[0]
#      14         SR = (signal * returns).dropna()
#      15         signal_profitfactor = SR[SR > 0].sum() / SR[SR < 0].abs().sum()
#
# Cell In[2], line 9, in MA_CROSSOVER(df, lookback_1, lookback_2)
#       6 dF['LMA'] = dF['Close'].rolling(lookback_2 - 1).mean()
#       8 Signal = pd.Series(np.full(len(dF),np.nan), index = dF.index)
# ----> 9 Signal.loc[dF['SMA'] > dF['LMA']] = 1
#      10 Signal.loc[dF['SMA'] < dF['LMA']] = -1
#      11 Signal = Signal.ffill()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1937, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1933         return
#    1935 if name == "loc":
#    1936     # must come after setting of missing
# -> 1937     indexer, value = self._maybe_mask_setitem_value(indexer, value)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:824, in _LocationIndexer._maybe_mask_setitem_value(self, indexer, value)
#     822                 value = self.obj.iloc._align_frame(indexer, value)
#     823                 indexer = (newkey, icols)
# --> 824 elif com.is_bool_indexer(indexer):
#     825     indexer = indexer.nonzero()[0]
#     827 return indexer, value
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/common.py:97, in is_bool_indexer(key)
#      93             name = None
#      94     return name
# ---> 97 def is_bool_indexer(key: Any) -> bool:
#      98     """
#      99     Check whether `key` is a valid boolean indexer.
#     100
#    (...)
#     123         and convert to an ndarray.
#     124     """
#     125     if isinstance(
#     126         key, (ABCSeries, np.ndarray, ABCIndex, ABCExtensionArray)
#     127     ) and not isinstance(key, ABCMultiIndex):
#
# KeyboardInterrupt:

# %%
symbol = 'BTC-USD'

df_btc = yf.download([symbol], start = '2016-01-31', end = '2020-01-31', interval="1d")
df_copybtc = df_btc.copy()

bestLB1, bestLB2, bestPF = OPTI_MACO(df_btc)

SIG, nb_t_btc = MA_CROSSOVER(df_btc, bestLB1, bestLB2)
SIG2, nb_t_btc_notopty = MA_CROSSOVER(df_copybtc, 73, 74)


df_btc['returns'] = np.log(df_btc['Close']).diff().shift(-1)
df_btc['system_returns'] = df_btc['returns']*SIG
plt.plot(np.exp(df_btc['system_returns']).cumprod(), label = 'Rendement BTC')
plt.legend(loc=2)
plt.show()

print(f"best lookback 1 is : {bestLB1}")
print(f"best lookback 2 is : {bestLB2}")
print(f"best profit factor is : {bestPF}")
print(f"the number of trades for these lookbacks is {nb_t_btc}")


df_copybtc['returns'] = np.log(df_copybtc['Close']).diff().shift(-1)
df_copybtc['system_returns'] = df_copybtc['returns']*SIG2
plt.plot(np.exp(df_copybtc['system_returns']).cumprod(), label = 'Rendement BTC for l1 = 73 , l2 = 74')
plt.legend(loc=2)
plt.show()
print(f"il y a eu {nb_t_btc_notopty} trade")
# Out:
# /var/folders/6x/40f088zn6lb1tw1zn99534440000gn/T/ipykernel_12621/1127301984.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_btc = yf.download([symbol], start = '2016-01-31', end = '2020-01-31', interval="1d")
# [*********************100%***********************]  1 of 1 completed
# best lookback 1 is : 73
# best lookback 2 is : 76
# best profit factor is : 1.3485540555573976
# the number of trades for these lookbacks is 37
# il y a eu 59 trade
